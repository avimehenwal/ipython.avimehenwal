# %% [markdown]
# YAML “YAML Ain’t Markup Language”
# ------------------------------------
#
# YAML is a data serialization language designed to be human-friendly and work well with modern programming languages for common everyday tasks:
#
# * __.yaml__ or __.yml__ extension
# * Tabs are not allowed. Only spaces
# * All key properties are case-sensetive
# * YAML uses three dashes (“---”) to separate directives from document content. This also serves to signal the start of a document if no directives are present.
# * Three dots ( “...”) indicate the end of a document without starting a new one, for use in communication channels.
# * [yaml spec](http://www.yaml.org/spec/1.2/spec.html)

# %% [raw]
# Sequence of Mappings (players’ statistics)
#     -
#       name: Mark McGwire
#       hr:   65
#       avg:  0.278
#     -
#       name: Sammy Sosa
#       hr:   63
#       avg:  0.288
#
# Example 2.8.  Play by Play Feed from a Game
#     ---
#     time: 20:03:20
#     player: Sammy Sosa
#     action: strike (miss)
#     ...
#     ---
#     time: 20:03:47
#     player: Sammy Sosa
#     action: grand slam
#     ...
#
# Example 2.7.  Two Documents in a Stream (each with a leading comment)
#     # Ranking of 1998 home runs
#     ---
#     - Mark McGwire
#     - Sammy Sosa
#     - Ken Griffey
#
#     # Team ranking
#     ---
#     - Chicago Cubs
#     - St Louis Cardinals
#
# Example 2.10.  Node for “Sammy Sosa” appears twice in this document
#     ---
#     hr:
#       - Mark McGwire
#       # Following node labeled SS
#       - &SS Sammy Sosa
#     rbi:
#       - *SS # Subsequent occurrence
#       - Ken Griffey

# %%
import yaml

# %%
data_yaml = """
search_terms:
- bat
- bats
- ball
- balls
- tredmill
bat:
  product.reflektion.com:
    cat: []
    sugg:
    - Bat
    - Batting
    - Battery
    - Bat BETA
    - Batting Pads
  staging-v2.reflektion.com:
    cat:
    - cricket bats
    - cricket batting pads
    - cricket batting gloves
    - e-bikes batteries
    - cricket batting shorts
    - cricket batting inners
    sugg:
    - batting
    - bat
    - bat senior
    - bat alpha
    - bat beta
    - bat grip
    - bat cover
    - bat flame
    - batting shorts
    - batting gloves/pads
bat:
  product.reflektion.com:
    cat: []
    sugg:
    - Bat
    - Batting
    - Battery
    - Bat BETA
    - Batting Pads
  staging-v2.reflektion.com:
    cat:
    - cricket bats
    - cricket batting pads
    - cricket batting gloves
    - e-bikes batteries
    - cricket batting shorts
    - cricket batting inners
    sugg:
    - batting
    - bat
    - bat senior
    - bat alpha
    - bat beta
    - bat grip
    - bat cover
    - bat flame
    - batting shorts
    - batting gloves/pads
bats:
  product.reflektion.com:
    cat:
    - Basketball
    sugg:
    - Bat
    - Base
    - Bars
    - Basic
    - Batting
  staging-v2.reflektion.com:
    cat:
    - cricket bats
    sugg: []
ball:
  product.reflektion.com:
    cat: []
    sugg:
    - Ball
    - Balls
    - Balls AAA
    - Balls Volt
    - Balls WHITE
  staging-v2.reflektion.com:
    cat:
    - golf balls
    - cricket balls
    - golf junior balls
    sugg:
    - balls
    - ball
    - balls white
    - balls personalised
    - balls grade
    - ball set
    - balls volt
    - ball retriever
    - ball set kg
    - balls tees
bat:
  product.reflektion.com:
    cat: []
    sugg:
    - Bat
    - Batting
    - Battery
    - Bat BETA
    - Batting Pads
  staging-v2.reflektion.com:
    cat:
    - cricket bats
    - cricket batting pads
    - cricket batting gloves
    - e-bikes batteries
    - cricket batting shorts
    - cricket batting inners
    sugg:
    - batting
    - bat
    - bat senior
    - bat alpha
    - bat beta
    - bat grip
    - bat cover
    - bat flame
    - batting shorts
    - batting gloves/pads
bats:
  product.reflektion.com:
    cat:
    - Basketball
    sugg:
    - Bat
    - Base
    - Bars
    - Basic
    - Batting
  staging-v2.reflektion.com:
    cat:
    - cricket bats
    sugg: []
ball:
  product.reflektion.com:
    cat: []
    sugg:
    - Ball
    - Balls
    - Balls AAA
    - Balls Volt
    - Balls WHITE
  staging-v2.reflektion.com:
    cat:
    - golf balls
    - cricket balls
    - golf junior balls
    sugg:
    - balls
    - ball
    - balls white
    - balls personalised
    - balls grade
    - ball set
    - balls volt
    - ball retriever
    - ball set kg
    - balls tees
balls:
  product.reflektion.com:
    cat: []
    sugg:
    - Balls
    - Balls AAA
    - Balls Volt
    - Balls WHITE
    - Balls Grade
  staging-v2.reflektion.com:
    cat:
    - golf balls
    - cricket balls
    - golf junior balls
    sugg:
    - balls
    - balls white
    - balls personalised
    - balls grade
    - balls volt
    - balls tees
    - balls dozen
    - balls white personalised
    - balls red
    - balls orange
bat:
  product.reflektion.com:
    cat: []
    sugg:
    - Bat
    - Batting
    - Battery
    - Bat BETA
    - Batting Pads
  staging-v2.reflektion.com:
    cat:
    - cricket bats
    - cricket batting pads
    - cricket batting gloves
    - e-bikes batteries
    - cricket batting shorts
    - cricket batting inners
    sugg:
    - batting
    - bat
    - bat senior
    - bat alpha
    - bat beta
    - bat grip
    - bat cover
    - bat flame
    - batting shorts
    - batting gloves/pads
bats:
  product.reflektion.com:
    cat:
    - Basketball
    sugg:
    - Bat
    - Base
    - Bars
    - Basic
    - Batting
  staging-v2.reflektion.com:
    cat:
    - cricket bats
    sugg: []
ball:
  product.reflektion.com:
    cat: []
    sugg:
    - Ball
    - Balls
    - Balls AAA
    - Balls Volt
    - Balls WHITE
  staging-v2.reflektion.com:
    cat:
    - golf balls
    - cricket balls
    - golf junior balls
    sugg:
    - balls
    - ball
    - balls white
    - balls personalised
    - balls grade
    - ball set
    - balls volt
    - ball retriever
    - ball set kg
    - balls tees
balls:
  product.reflektion.com:
    cat: []
    sugg:
    - Balls
    - Balls AAA
    - Balls Volt
    - Balls WHITE
    - Balls Grade
  staging-v2.reflektion.com:
    cat:
    - golf balls
    - cricket balls
    - golf junior balls
    sugg:
    - balls
    - balls white
    - balls personalised
    - balls grade
    - balls volt
    - balls tees
    - balls dozen
    - balls white personalised
    - balls red
    - balls orange
bat:
  product.reflektion.com:
    cat: []
    sugg:
    - Bat
    - Batting
    - Battery
    - Bat BETA
    - Batting Pads
  staging-v2.reflektion.com:
    cat:
    - cricket bats
    - cricket batting pads
    - cricket batting gloves
    - e-bikes batteries
    - cricket batting shorts
    - cricket batting inners
    sugg:
    - batting
    - bat
    - bat senior
    - bat alpha
    - bat beta
    - bat grip
    - bat cover
    - bat flame
    - batting shorts
    - batting gloves/pads
bats:
  product.reflektion.com:
    cat:
    - Basketball
    sugg:
    - Bat
    - Base
    - Bars
    - Basic
    - Batting
  staging-v2.reflektion.com:
    cat:
    - cricket bats
    sugg: []
tredmill:
  product.reflektion.com:
    cat: []
    sugg:
    - Treadmill
  staging-v2.reflektion.com:
    cat:
    - fitness treadmill
    sugg:
    - treadmill
    - treadmill pink
    - treadmill mat
    - treadmill white"""

# %%
data_load = yaml.safe_load(data_yaml)

# %%
import pprint
print type(data_load)
pprint.pprint(data_load)
# Out:
# <type 'dict'>
# {'ball': {'product.reflektion.com': {'cat': [],
#                                      'sugg': ['Ball',
#                                               'Balls',
#                                               'Balls AAA',
#                                               'Balls Volt',
#                                               'Balls WHITE']},
#           'staging-v2.reflektion.com': {'cat': ['golf balls',
#                                                 'cricket balls',
#                                                 'golf junior balls'],
#                                         'sugg': ['balls',
#                                                  'ball',
#                                                  'balls white',
#                                                  'balls personalised',
#                                                  'balls grade',
#                                                  'ball set',
# ...

# %%
data_dump = yaml.safe_dump(data_load, default_flow_style=False)

# %%
print type(data_dump)
print data_dump
# Out:
# <type 'str'>
# ball:
#   product.reflektion.com:
#     cat: []
#     sugg:
#     - Ball
#     - Balls
#     - Balls AAA
#     - Balls Volt
#     - Balls WHITE
#   staging-v2.reflektion.com:
#     cat:
#     - golf balls
#     - cricket balls
#     - golf junior balls
#     sugg:
#     - balls
#     - ball
#     - balls white
#     - balls personalised
#     - balls grade
#     - ball set
#     - balls volt
#     - ball retriever
#     - ball set kg
#     - balls tees
# balls:
#   product.reflektion.com:
#     cat: []
#     sugg:
#     - Balls
#     - Balls AAA
#     - Balls Volt
#     - Balls WHITE
#     - Balls Grade
#   staging-v2.reflektion.com:
#     cat:
#     - golf balls
#     - cricket balls
#     - golf junior balls
#     sugg:
#     - balls
#     - balls white
#     - balls personalised
#     - balls grade
#     - balls volt
#     - balls tees
#     - balls dozen
#     - balls white personalised
#     - balls red
#     - balls orange
# bat:
#   product.reflektion.com:
# ...
